# %%
import Sustainable_Code_Demo as scd
import Sustainable_Code_Demo.hamiltonians as hams
import numpy as np
import scipy as scp

# %%
help(hams.one_spin_op)
# Out:
# Help on function one_spin_op in module Sustainable_Code_Demo.hamiltonians:
#
# one_spin_op(L, idx, Op)
#     Compute the single-spin operator Op at the position idx in the tensor-product basis space of L spins.

# %%
hams.sx.todense()
# Out:
# array([[0. , 0.5],
#        [0.5, 0. ]])

# %%
L = 5
idx = 0
op = hams.sx
hams.one_spin_op(L, idx, op)
# Out:
# <COOrdinate sparse array of dtype 'float64'
# 	with 32 stored elements and shape (32, 32)>

# %%
#L = 5
#J = 0.0
#hx_arr = np.array([0.5, 0, 0, 1., 0])
#ham = hams.tfim_hamiltonian(L, J, hx_arr, periodic=False)
#expected = scp.sparse.csr_matrix((2 ** L, 2 ** L), dtype=complex)
#expected += hx_arr[0] * hams.one_spin_op(L, 0, hams.sx)
#expected += hx_arr[3] * hams.one_spin_op(L, 3, hams.sx)
